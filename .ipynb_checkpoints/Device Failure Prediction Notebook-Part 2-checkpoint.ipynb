# %%
import boto3
import pandas as pd
from sagemaker import get_execution_role
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  
import seaborn as sns
import sagemaker
from sagemaker.amazon.amazon_estimator import get_image_uri

# %% [markdown]
# # Model Tuning and Training
# Built-in Algorithms in Amazon SageMaker: https://docs.aws.amazon.com/sagemaker/latest/dg/algos.html

# %%
role = get_execution_role()

region = boto3.Session().region_name
bucket = 'ml-demo-device-failures'

sess = sagemaker.Session()
sm_client=sess.sagemaker_client

s3_input_train = boto3.Session().resource('s3').Bucket(bucket).Object('train/train.dat')
train_data_s3_path="s3://{}/{}".format(s3_input_train.bucket_name,s3_input_train.key)

s3_input_validation = boto3.Session().resource('s3').Bucket(bucket).Object('validation/validation.dat')
validation_data_s3_path="s3://{}/{}".format(s3_input_validation.bucket_name,s3_input_validation.key)

s3_input_test = boto3.Session().resource('s3').Bucket(bucket).Object('test/test.csv')
test_data_s3_path = 'https://s3-{}.amazonaws.com/{}/{}'.format(region,s3_input_test.bucket_name,s3_input_test.key)

# %% [markdown]
# About XGboost Algorithm: https://arxiv.org/pdf/1603.02754.pdf
# https://aws.amazon.com/sagemaker/pricing/instance-types/
#
# During Model Training it is recommendable to use a Compute Optimized (ml.c5 type) or Accelerated Computing Instance (ml.p3) depeding on the training scenario.

# %%
container = get_image_uri(region, 'xgboost')

xgb_estimator = sagemaker.estimator.Estimator(container,
                                    role, 
                                    train_instance_count=1, 
                                    train_instance_type='ml.c5.9xlarge',
                                    output_path='s3://{}/models/output'.format(bucket),
                                    sagemaker_session=sess,
                                    tags=[{"Key":"project","Value":"oxford_demo"}])

# %% [markdown]
# ## Model Hyperparameter Tuning
#
# Sagemaker Hyperparameter tuning uses an Amazon SageMaker implementation of Bayesian optimization.<br/>
# https://docs.aws.amazon.com/sagemaker/latest/dg/xgboost_hyperparameters.html<br/>

# %%
from sagemaker.tuner import HyperparameterTuner, ContinuousParameter, IntegerParameter

xgb_estimator.set_hyperparameters(objective='binary:logistic',seed=123,base_score=0.5,n_thread=4,rate_drop=0.2)

param_dist_xgb = {
              'subsample': ContinuousParameter(0.3, 0.8),
              'max_depth': IntegerParameter(3, 9),
              'colsample_bytree': ContinuousParameter(0.45, 0.5),
              'min_child_weight': IntegerParameter(1, 3),
              'num_round':  IntegerParameter(150, 500),
              'lambda':   ContinuousParameter(0.05, 0.4)
              }

# Configure Hyperparameter Tuner
xgb_tuner = HyperparameterTuner(estimator=xgb_estimator,  # previously-configured Estimator object
                               objective_metric_name='validation:auc',
                               hyperparameter_ranges=param_dist_xgb,
                               max_jobs=100,
                               max_parallel_jobs=5,
                               base_tuning_job_name='device-failure-detection-xgboost-',
                               tags=[{"Key":"project","Value":"oxford_demo"}],
                               early_stopping_type="Auto"
                               )

# %% [markdown]
# ## Model Training

# %%
xgb_tuner.fit(inputs={'train': train_data_s3_path, 'validation': validation_data_s3_path})
# Out:
# INFO:sagemaker:Creating hyperparameter tuning job with name: device-failure-detec-181215-0909

# %% [markdown]
# Checking Results of All Trained Models

# %%
xgb_tuner_analytics = xgb_tuner.analytics()
modelTuningOutputs=xgb_tuner_analytics.dataframe()
modelTuningOutputs.sort_values('FinalObjectiveValue',inplace=True, ascending=False)
modelTuningOutputs
# Out:
#     FinalObjectiveValue  TrainingElapsedTimeSeconds           TrainingEndTime  \
# 6              0.703559                        33.0 2018-12-15 09:17:09+00:00
# 15             0.681576                        29.0 2018-12-15 09:12:02+00:00
# 16             0.667798                        34.0 2018-12-15 09:12:03+00:00
# 14             0.652028                        32.0 2018-12-15 09:12:03+00:00
# 12             0.612938                        31.0 2018-12-15 09:14:38+00:00
# 17             0.578881                        32.0 2018-12-15 09:11:58+00:00
# 11             0.560356                        37.0 2018-12-15 09:14:41+00:00
# 5              0.554717                        31.0 2018-12-15 09:17:13+00:00
# 13             0.550368                        36.0 2018-12-15 09:11:56+00:00
# 7              0.537577                        35.0 2018-12-15 09:17:11+00:00
# 10             0.524053                        36.0 2018-12-15 09:14:35+00:00
# 8              0.448597                        31.0 2018-12-15 09:15:23+00:00
# 9              0.440027                        36.0 2018-12-15 09:14:59+00:00
# 0                   NaN                         NaN                       NaT
# 1                   NaN                         NaN                       NaT
# 2                   NaN                         NaN                       NaT
# 3                   NaN                        30.0 2018-12-15 09:17:20+00:00
# 4                   NaN                         NaN                       NaT
#
#                                   TrainingJobName TrainingJobStatus  \
# 6   device-failure-detec-181215-0909-012-94c5347f         Completed
# 15  device-failure-detec-181215-0909-003-0d2baa86         Completed
# 16  device-failure-detec-181215-0909-002-33d60aa4         Completed
# 14  device-failure-detec-181215-0909-004-dbd69f13         Completed
# 12  device-failure-detec-181215-0909-006-70705352         Completed
# 17  device-failure-detec-181215-0909-001-ce0a8340         Completed
# 11  device-failure-detec-181215-0909-007-d8b48b36         Completed
# 5   device-failure-detec-181215-0909-013-5b70dee1         Completed
# 13  device-failure-detec-181215-0909-005-cceae66c         Completed
# 7   device-failure-detec-181215-0909-011-64dfadeb         Completed
# 10  device-failure-detec-181215-0909-008-ea593f8f         Completed
# 8   device-failure-detec-181215-0909-010-42b39f4b           Stopped
# 9   device-failure-detec-181215-0909-009-a17be29d         Completed
# 0   device-failure-detec-181215-0909-017-9bc7de2f        InProgress
# 1   device-failure-detec-181215-0909-016-057a3b6f        InProgress
# 2   device-failure-detec-181215-0909-015-a48f13bf        InProgress
# 3   device-failure-detec-181215-0909-014-e8a9a26b         Completed
# 4   device-failure-detec-181215-0909-014-bb87f6e8        InProgress
#
#            TrainingStartTime  colsample_bytree    lambda  max_depth  \
# 6  2018-12-15 09:16:36+00:00          0.498186  0.351619        8.0
# 15 2018-12-15 09:11:33+00:00          0.482661  0.350654        4.0
# 16 2018-12-15 09:11:29+00:00          0.498570  0.120153        5.0
# 14 2018-12-15 09:11:31+00:00          0.497478  0.386242        8.0
# 12 2018-12-15 09:14:07+00:00          0.468939  0.365298        3.0
# 17 2018-12-15 09:11:26+00:00          0.491743  0.157158        9.0
# 11 2018-12-15 09:14:04+00:00          0.483201  0.393742        4.0
# 5  2018-12-15 09:16:42+00:00          0.452823  0.098985        5.0
# 13 2018-12-15 09:11:20+00:00          0.477237  0.377333        6.0
# 7  2018-12-15 09:16:36+00:00          0.471290  0.240089        9.0
# 10 2018-12-15 09:13:59+00:00          0.474900  0.369816        4.0
# 8  2018-12-15 09:14:52+00:00          0.471089  0.260035        4.0
# 9  2018-12-15 09:14:23+00:00          0.451745  0.255196        3.0
# 0                        NaT          0.480991  0.344421        9.0
# 1                        NaT          0.499394  0.135361        9.0
# 2                        NaT          0.497186  0.356136        8.0
# 3  2018-12-15 09:16:50+00:00          0.482976  0.107761        6.0
# 4  2018-12-15 09:17:23+00:00          0.457185  0.130586        9.0
#
#     min_child_weight  num_round  subsample
# 6                3.0      381.0   0.583871
# 15               3.0      330.0   0.657589
# 16               2.0      397.0   0.632957
# 14               2.0      331.0   0.596675
# 12               3.0      424.0   0.732384
# 17               2.0      261.0   0.756727
# 11               3.0      348.0   0.687172
# 5                3.0      311.0   0.651405
# 13               1.0      188.0   0.354028
# 7                2.0      279.0   0.560982
# 10               3.0      338.0   0.609789
# 8                3.0      371.0   0.755745
# 9                3.0      368.0   0.492577
# 0                3.0      451.0   0.605273
# 1                3.0      393.0   0.401451
# 2                3.0      379.0   0.584191
# 3                1.0      307.0   0.714318
# 4                1.0      465.0   0.634295

# %% [markdown]
# # Model Deployment to An Endpoint for Inference

# %%
from time import strftime, gmtime
endpoint_name = 'device-failure-detection-endpoint-' + strftime("%Y-%m-%d-%H-%M-%S", gmtime())
device_failure_predictor = xgb_tuner.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge',endpoint_name=endpoint_name)
# Out:
# INFO:sagemaker:Creating model with name: xgboost-2018-12-15-09-21-45-513
# 2018-12-15 09:17:09 Starting - Preparing the instances for training
# 2018-12-15 09:17:09 Downloading - Downloading input data
# 2018-12-15 09:17:09 Training - Training image download completed. Training in progress.
# 2018-12-15 09:17:09 Uploading - Uploading generated training model
# 2018-12-15 09:17:09 Completed - Training job completedArguments: train
# [2018-12-15:09:16:56:INFO] Running standalone xgboost training.
# [2018-12-15:09:16:56:INFO] Setting up HPO optimized metric to be : auc
# [2018-12-15:09:16:56:INFO] File size need to be processed in the node: 35.72mb. Available memory size in the node: 62036.21mb
# [09:16:56] S3DistributionType set as FullyReplicated
# [09:16:56] 87692x49 matrix with 2199997 entries loaded from /opt/ml/input/data/train
# [09:16:56] S3DistributionType set as FullyReplicated
# [09:16:56] 10469x49 matrix with 264441 entries loaded from /opt/ml/input/data/validation
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [0]#011train-auc:0.629102#011validation-auc:0.5
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [1]#011train-auc:0.718667#011validation-auc:0.496273
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [2]#011train-auc:0.762669#011validation-auc:0.494743
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=6
# [3]#011train-auc:0.762739#011validation-auc:0.494743
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [4]#011train-auc:0.79512#011validation-auc:0.492784
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [5]#011train-auc:0.832588#011validation-auc:0.48791
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [6]#011train-auc:0.839351#011validation-auc:0.48748
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [7]#011train-auc:0.839072#011validation-auc:0.483227
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [8]#011train-auc:0.862371#011validation-auc:0.559591
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=7
# [9]#011train-auc:0.862432#011validation-auc:0.558125
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=8
# [10]#011train-auc:0.879971#011validation-auc:0.629488
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=7
# [11]#011train-auc:0.921163#011validation-auc:0.616689
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [12]#011train-auc:0.920726#011validation-auc:0.605762
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [13]#011train-auc:0.920279#011validation-auc:0.595567
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=8
# [14]#011train-auc:0.92341#011validation-auc:0.66188
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [15]#011train-auc:0.927587#011validation-auc:0.605276
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=7
# [16]#011train-auc:0.944898#011validation-auc:0.580012
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=8
# [17]#011train-auc:0.96149#011validation-auc:0.675921
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=8
# [18]#011train-auc:0.966964#011validation-auc:0.678183
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=8
# [19]#011train-auc:0.973207#011validation-auc:0.599406
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=7
# [20]#011train-auc:0.972329#011validation-auc:0.613328
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=7
# [21]#011train-auc:0.974344#011validation-auc:0.589132
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [22]#011train-auc:0.976018#011validation-auc:0.54578
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [23]#011train-auc:0.980201#011validation-auc:0.549595
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [24]#011train-auc:0.981271#011validation-auc:0.499267
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [25]#011train-auc:0.981838#011validation-auc:0.53733
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [26]#011train-auc:0.981647#011validation-auc:0.556286
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [27]#011train-auc:0.984543#011validation-auc:0.528633
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [28]#011train-auc:0.98667#011validation-auc:0.610891
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [29]#011train-auc:0.989251#011validation-auc:0.578061
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [30]#011train-auc:0.988899#011validation-auc:0.616068
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [31]#011train-auc:0.987824#011validation-auc:0.582441
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=4
# [32]#011train-auc:0.990322#011validation-auc:0.578762
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=4
# [33]#011train-auc:0.989901#011validation-auc:0.586933
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=4
# [34]#011train-auc:0.99195#011validation-auc:0.59888
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [35]#011train-auc:0.991734#011validation-auc:0.621579
# [09:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=4
# [36]#011train-auc:0.994082#011validation-auc:0.634697
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [37]#011train-auc:0.994075#011validation-auc:0.619532
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [38]#011train-auc:0.995298#011validation-auc:0.632642
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [39]#011train-auc:0.995512#011validation-auc:0.664373
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [40]#011train-auc:0.996151#011validation-auc:0.674982
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [41]#011train-auc:0.996645#011validation-auc:0.67898
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [42]#011train-auc:0.996959#011validation-auc:0.686403
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [43]#011train-auc:0.997288#011validation-auc:0.698063
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [44]#011train-auc:0.997329#011validation-auc:0.662812
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=4
# [45]#011train-auc:0.997323#011validation-auc:0.665711
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=4
# [46]#011train-auc:0.997706#011validation-auc:0.64924
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [47]#011train-auc:0.997808#011validation-auc:0.637198
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [48]#011train-auc:0.997864#011validation-auc:0.621285
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [49]#011train-auc:0.998118#011validation-auc:0.625235
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=4
# [50]#011train-auc:0.998341#011validation-auc:0.600672
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [51]#011train-auc:0.998543#011validation-auc:0.621922
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [52]#011train-auc:0.998516#011validation-auc:0.62044
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=4
# [53]#011train-auc:0.998526#011validation-auc:0.615168
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [54]#011train-auc:0.998626#011validation-auc:0.634474
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=4
# [55]#011train-auc:0.998726#011validation-auc:0.635812
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=4
# [56]#011train-auc:0.998702#011validation-auc:0.633502
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [57]#011train-auc:0.999035#011validation-auc:0.663114
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [58]#011train-auc:0.999199#011validation-auc:0.664739
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=4
# [59]#011train-auc:0.99931#011validation-auc:0.668578
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [60]#011train-auc:0.999226#011validation-auc:0.671668
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=4
# [61]#011train-auc:0.999294#011validation-auc:0.684698
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [62]#011train-auc:0.999413#011validation-auc:0.676559
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [63]#011train-auc:0.999439#011validation-auc:0.6915
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [64]#011train-auc:0.999486#011validation-auc:0.701536
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [65]#011train-auc:0.999516#011validation-auc:0.687406
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [66]#011train-auc:0.999582#011validation-auc:0.683313
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [67]#011train-auc:0.999592#011validation-auc:0.686005
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=4
# [68]#011train-auc:0.999624#011validation-auc:0.674329
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [69]#011train-auc:0.999641#011validation-auc:0.67812
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=4
# [70]#011train-auc:0.999676#011validation-auc:0.662191
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [71]#011train-auc:0.9997#011validation-auc:0.659276
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=6
# [72]#011train-auc:0.999757#011validation-auc:0.643745
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [73]#011train-auc:0.999794#011validation-auc:0.641483
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=4
# [74]#011train-auc:0.999789#011validation-auc:0.646134
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=4
# [75]#011train-auc:0.999793#011validation-auc:0.639014
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [76]#011train-auc:0.999801#011validation-auc:0.657635
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [77]#011train-auc:0.999815#011validation-auc:0.647313
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [78]#011train-auc:0.99981#011validation-auc:0.638695
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [79]#011train-auc:0.999805#011validation-auc:0.65918
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=4
# [80]#011train-auc:0.999813#011validation-auc:0.663752
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [81]#011train-auc:0.999848#011validation-auc:0.674137
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=6
# [82]#011train-auc:0.999864#011validation-auc:0.679075
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [83]#011train-auc:0.999885#011validation-auc:0.698366
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [84]#011train-auc:0.999888#011validation-auc:0.69158
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=6
# [85]#011train-auc:0.999902#011validation-auc:0.67804
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [86]#011train-auc:0.999908#011validation-auc:0.671907
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [87]#011train-auc:0.999908#011validation-auc:0.671445
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [88]#011train-auc:0.99992#011validation-auc:0.688219
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [89]#011train-auc:0.999926#011validation-auc:0.697792
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [90]#011train-auc:0.999936#011validation-auc:0.690178
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [91]#011train-auc:0.999949#011validation-auc:0.683504
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [92]#011train-auc:0.999946#011validation-auc:0.679474
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [93]#011train-auc:0.999941#011validation-auc:0.682373
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [94]#011train-auc:0.999947#011validation-auc:0.678884
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=6
# [95]#011train-auc:0.999961#011validation-auc:0.668483
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [96]#011train-auc:0.999969#011validation-auc:0.662366
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [97]#011train-auc:0.999975#011validation-auc:0.691229
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [98]#011train-auc:0.999979#011validation-auc:0.696821
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [99]#011train-auc:0.999983#011validation-auc:0.696518
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [100]#011train-auc:0.999983#011validation-auc:0.703479
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [101]#011train-auc:0.999985#011validation-auc:0.703415
# [09:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [102]#011train-auc:0.999985#011validation-auc:0.699513
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [103]#011train-auc:0.99999#011validation-auc:0.693316
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [104]#011train-auc:0.99999#011validation-auc:0.68086
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [105]#011train-auc:0.999992#011validation-auc:0.679872
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [106]#011train-auc:0.999993#011validation-auc:0.69784
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [107]#011train-auc:0.999995#011validation-auc:0.704658
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [108]#011train-auc:0.999996#011validation-auc:0.718452
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [109]#011train-auc:0.999996#011validation-auc:0.714486
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [110]#011train-auc:0.999998#011validation-auc:0.712415
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [111]#011train-auc:0.999999#011validation-auc:0.698111
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [112]#011train-auc:0.999999#011validation-auc:0.691245
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [113]#011train-auc:0.999999#011validation-auc:0.69115
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [114]#011train-auc:0.999999#011validation-auc:0.688267
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [115]#011train-auc:0.999999#011validation-auc:0.691596
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [116]#011train-auc:0.999999#011validation-auc:0.675762
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [117]#011train-auc:0.999998#011validation-auc:0.673261
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [118]#011train-auc:0.999999#011validation-auc:0.675969
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [119]#011train-auc:0.999999#011validation-auc:0.689254
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [120]#011train-auc:0.999999#011validation-auc:0.690178
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [121]#011train-auc:0.999998#011validation-auc:0.691261
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [122]#011train-auc:0.999999#011validation-auc:0.694606
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [123]#011train-auc:0.999999#011validation-auc:0.693921
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [124]#011train-auc:0.999999#011validation-auc:0.702348
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [125]#011train-auc:0.999999#011validation-auc:0.713371
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [126]#011train-auc:0.999999#011validation-auc:0.715442
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [127]#011train-auc:0.999999#011validation-auc:0.706187
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [128]#011train-auc:0.999999#011validation-auc:0.705215
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [129]#011train-auc:0.999998#011validation-auc:0.703702
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [130]#011train-auc:0.999999#011validation-auc:0.703033
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [131]#011train-auc:0.999998#011validation-auc:0.692249
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [132]#011train-auc:0.999998#011validation-auc:0.701408
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [133]#011train-auc:0.999998#011validation-auc:0.693698
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [134]#011train-auc:0.999999#011validation-auc:0.693507
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [135]#011train-auc:0.999999#011validation-auc:0.697537
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [136]#011train-auc:0.999999#011validation-auc:0.690178
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [137]#011train-auc:0.999999#011validation-auc:0.692822
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [138]#011train-auc:0.999999#011validation-auc:0.701344
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [139]#011train-auc:1#011validation-auc:0.711029
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [140]#011train-auc:0.999999#011validation-auc:0.708767
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [141]#011train-auc:0.999999#011validation-auc:0.706028
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [142]#011train-auc:0.999999#011validation-auc:0.696327
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [143]#011train-auc:0.999999#011validation-auc:0.692743
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [144]#011train-auc:1#011validation-auc:0.698764
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [145]#011train-auc:1#011validation-auc:0.694845
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [146]#011train-auc:1#011validation-auc:0.692663
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [147]#011train-auc:1#011validation-auc:0.694168
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [148]#011train-auc:1#011validation-auc:0.692392
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [149]#011train-auc:1#011validation-auc:0.693284
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [150]#011train-auc:1#011validation-auc:0.691357
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [151]#011train-auc:1#011validation-auc:0.701759
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [152]#011train-auc:1#011validation-auc:0.697776
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [153]#011train-auc:1#011validation-auc:0.708098
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [154]#011train-auc:1#011validation-auc:0.708226
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [155]#011train-auc:1#011validation-auc:0.708305
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [156]#011train-auc:1#011validation-auc:0.701376
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [157]#011train-auc:1#011validation-auc:0.690895
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [158]#011train-auc:1#011validation-auc:0.696598
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [159]#011train-auc:1#011validation-auc:0.692201
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [160]#011train-auc:1#011validation-auc:0.70093
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [161]#011train-auc:1#011validation-auc:0.69776
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [162]#011train-auc:1#011validation-auc:0.697075
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [163]#011train-auc:1#011validation-auc:0.701185
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [164]#011train-auc:1#011validation-auc:0.691038
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [165]#011train-auc:1#011validation-auc:0.696104
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [166]#011train-auc:1#011validation-auc:0.697044
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [167]#011train-auc:1#011validation-auc:0.688649
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [168]#011train-auc:1#011validation-auc:0.691325
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [169]#011train-auc:1#011validation-auc:0.684507
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [170]#011train-auc:1#011validation-auc:0.687948
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [171]#011train-auc:1#011validation-auc:0.689844
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [172]#011train-auc:1#011validation-auc:0.69381
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [173]#011train-auc:1#011validation-auc:0.683982
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [174]#011train-auc:1#011validation-auc:0.695992
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [175]#011train-auc:1#011validation-auc:0.692265
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [176]#011train-auc:1#011validation-auc:0.700867
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [177]#011train-auc:1#011validation-auc:0.706665
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [178]#011train-auc:1#011validation-auc:0.706426
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [179]#011train-auc:1#011validation-auc:0.704068
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [180]#011train-auc:1#011validation-auc:0.703383
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [181]#011train-auc:1#011validation-auc:0.704403
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [182]#011train-auc:1#011validation-auc:0.69655
# [09:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [183]#011train-auc:1#011validation-auc:0.69964
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [184]#011train-auc:1#011validation-auc:0.706012
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [185]#011train-auc:1#011validation-auc:0.691118
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [186]#011train-auc:1#011validation-auc:0.695419
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [187]#011train-auc:1#011validation-auc:0.698541
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [188]#011train-auc:1#011validation-auc:0.700245
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [189]#011train-auc:1#011validation-auc:0.703559
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [190]#011train-auc:1#011validation-auc:0.710488
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [191]#011train-auc:1#011validation-auc:0.708019
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [192]#011train-auc:1#011validation-auc:0.699783
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [193]#011train-auc:1#011validation-auc:0.703049
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [194]#011train-auc:1#011validation-auc:0.711491
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [195]#011train-auc:1#011validation-auc:0.706792
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [196]#011train-auc:1#011validation-auc:0.701376
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [197]#011train-auc:1#011validation-auc:0.696709
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [198]#011train-auc:1#011validation-auc:0.698636
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [199]#011train-auc:1#011validation-auc:0.701281
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [200]#011train-auc:1#011validation-auc:0.70109
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [201]#011train-auc:1#011validation-auc:0.693444
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [202]#011train-auc:1#011validation-auc:0.691548
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [203]#011train-auc:1#011validation-auc:0.693093
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [204]#011train-auc:1#011validation-auc:0.702778
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [205]#011train-auc:1#011validation-auc:0.702205
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [206]#011train-auc:1#011validation-auc:0.705661
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [207]#011train-auc:1#011validation-auc:0.705406
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [208]#011train-auc:1#011validation-auc:0.707047
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [209]#011train-auc:1#011validation-auc:0.703144
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [210]#011train-auc:1#011validation-auc:0.700134
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [211]#011train-auc:1#011validation-auc:0.702635
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [212]#011train-auc:1#011validation-auc:0.708974
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [213]#011train-auc:1#011validation-auc:0.704594
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [214]#011train-auc:1#011validation-auc:0.701392
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [215]#011train-auc:1#011validation-auc:0.70109
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [216]#011train-auc:1#011validation-auc:0.707413
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [217]#011train-auc:1#011validation-auc:0.706267
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [218]#011train-auc:1#011validation-auc:0.707796
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [219]#011train-auc:1#011validation-auc:0.703192
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [220]#011train-auc:1#011validation-auc:0.702109
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [221]#011train-auc:1#011validation-auc:0.707382
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [222]#011train-auc:1#011validation-auc:0.705916
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [223]#011train-auc:1#011validation-auc:0.700484
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [224]#011train-auc:1#011validation-auc:0.699146
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [225]#011train-auc:1#011validation-auc:0.698732
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [226]#011train-auc:1#011validation-auc:0.694081
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [227]#011train-auc:1#011validation-auc:0.692424
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [228]#011train-auc:1#011validation-auc:0.694208
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [229]#011train-auc:1#011validation-auc:0.696343
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [230]#011train-auc:1#011validation-auc:0.69878
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [231]#011train-auc:1#011validation-auc:0.694798
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [232]#011train-auc:1#011validation-auc:0.691946
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [233]#011train-auc:1#011validation-auc:0.691994
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [234]#011train-auc:1#011validation-auc:0.686626
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [235]#011train-auc:1#011validation-auc:0.688601
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [236]#011train-auc:1#011validation-auc:0.698477
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [237]#011train-auc:1#011validation-auc:0.697983
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [238]#011train-auc:1#011validation-auc:0.69964
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [239]#011train-auc:1#011validation-auc:0.70187
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [240]#011train-auc:1#011validation-auc:0.699465
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [241]#011train-auc:1#011validation-auc:0.700166
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [242]#011train-auc:1#011validation-auc:0.701042
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [243]#011train-auc:1#011validation-auc:0.699767
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [244]#011train-auc:1#011validation-auc:0.698302
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [245]#011train-auc:1#011validation-auc:0.694208
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [246]#011train-auc:1#011validation-auc:0.693921
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [247]#011train-auc:1#011validation-auc:0.690465
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [248]#011train-auc:1#011validation-auc:0.695737
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [249]#011train-auc:1#011validation-auc:0.69569
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [250]#011train-auc:1#011validation-auc:0.690513
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [251]#011train-auc:1#011validation-auc:0.691644
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [252]#011train-auc:1#011validation-auc:0.69432
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [253]#011train-auc:1#011validation-auc:0.693698
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [254]#011train-auc:1#011validation-auc:0.695801
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [255]#011train-auc:1#011validation-auc:0.694925
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [256]#011train-auc:1#011validation-auc:0.694686
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [257]#011train-auc:1#011validation-auc:0.696916
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [258]#011train-auc:1#011validation-auc:0.689127
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [259]#011train-auc:1#011validation-auc:0.685782
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [260]#011train-auc:1#011validation-auc:0.684874
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [261]#011train-auc:1#011validation-auc:0.690608
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [262]#011train-auc:1#011validation-auc:0.701185
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [263]#011train-auc:1#011validation-auc:0.705024
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [264]#011train-auc:1#011validation-auc:0.703638
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [265]#011train-auc:1#011validation-auc:0.704976
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [266]#011train-auc:1#011validation-auc:0.703941
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [267]#011train-auc:1#011validation-auc:0.704642
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [268]#011train-auc:1#011validation-auc:0.704498
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [269]#011train-auc:1#011validation-auc:0.699481
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [270]#011train-auc:1#011validation-auc:0.69561
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [271]#011train-auc:1#011validation-auc:0.694813
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [272]#011train-auc:1#011validation-auc:0.695291
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [273]#011train-auc:1#011validation-auc:0.692552
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [274]#011train-auc:1#011validation-auc:0.696438
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [275]#011train-auc:1#011validation-auc:0.700006
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [276]#011train-auc:1#011validation-auc:0.695642
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [277]#011train-auc:1#011validation-auc:0.699305
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [278]#011train-auc:1#011validation-auc:0.701169
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [279]#011train-auc:1#011validation-auc:0.70007
# [09:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [280]#011train-auc:1#011validation-auc:0.699114
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [281]#011train-auc:1#011validation-auc:0.699943
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [282]#011train-auc:1#011validation-auc:0.703861
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [283]#011train-auc:1#011validation-auc:0.697872
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [284]#011train-auc:1#011validation-auc:0.696948
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [285]#011train-auc:1#011validation-auc:0.696693
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [286]#011train-auc:1#011validation-auc:0.697346
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [287]#011train-auc:1#011validation-auc:0.688569
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [288]#011train-auc:1#011validation-auc:0.68669
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [289]#011train-auc:1#011validation-auc:0.685192
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [290]#011train-auc:1#011validation-auc:0.686307
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [291]#011train-auc:1#011validation-auc:0.684858
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [292]#011train-auc:1#011validation-auc:0.693794
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [293]#011train-auc:1#011validation-auc:0.689764
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [294]#011train-auc:1#011validation-auc:0.69381
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [295]#011train-auc:1#011validation-auc:0.686769
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [296]#011train-auc:1#011validation-auc:0.692759
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [297]#011train-auc:1#011validation-auc:0.698382
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [298]#011train-auc:1#011validation-auc:0.70872
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [299]#011train-auc:1#011validation-auc:0.712606
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [300]#011train-auc:1#011validation-auc:0.709851
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [301]#011train-auc:1#011validation-auc:0.708146
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [302]#011train-auc:1#011validation-auc:0.704403
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [303]#011train-auc:1#011validation-auc:0.703654
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [304]#011train-auc:1#011validation-auc:0.700612
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [305]#011train-auc:1#011validation-auc:0.702937
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [306]#011train-auc:1#011validation-auc:0.705422
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [307]#011train-auc:1#011validation-auc:0.70418
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [308]#011train-auc:1#011validation-auc:0.705613
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [309]#011train-auc:1#011validation-auc:0.707987
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [310]#011train-auc:1#011validation-auc:0.707525
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [311]#011train-auc:1#011validation-auc:0.703336
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [312]#011train-auc:1#011validation-auc:0.702157
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [313]#011train-auc:1#011validation-auc:0.698796
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [314]#011train-auc:1#011validation-auc:0.702842
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [315]#011train-auc:1#011validation-auc:0.698238
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [316]#011train-auc:1#011validation-auc:0.700261
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [317]#011train-auc:1#011validation-auc:0.704865
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [318]#011train-auc:1#011validation-auc:0.699943
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [319]#011train-auc:1#011validation-auc:0.699783
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [320]#011train-auc:1#011validation-auc:0.697983
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [321]#011train-auc:1#011validation-auc:0.699529
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [322]#011train-auc:1#011validation-auc:0.704307
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [323]#011train-auc:1#011validation-auc:0.703367
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [324]#011train-auc:1#011validation-auc:0.711619
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [325]#011train-auc:1#011validation-auc:0.713801
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [326]#011train-auc:1#011validation-auc:0.711252
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [327]#011train-auc:1#011validation-auc:0.71181
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [328]#011train-auc:1#011validation-auc:0.71095
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [329]#011train-auc:1#011validation-auc:0.708003
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [330]#011train-auc:1#011validation-auc:0.707159
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [331]#011train-auc:1#011validation-auc:0.706091
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [332]#011train-auc:1#011validation-auc:0.702826
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [333]#011train-auc:1#011validation-auc:0.701456
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [334]#011train-auc:1#011validation-auc:0.701679
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [335]#011train-auc:1#011validation-auc:0.703256
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [336]#011train-auc:1#011validation-auc:0.705104
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [337]#011train-auc:1#011validation-auc:0.707318
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [338]#011train-auc:1#011validation-auc:0.712718
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [339]#011train-auc:1#011validation-auc:0.717736
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [340]#011train-auc:1#011validation-auc:0.714438
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [341]#011train-auc:1#011validation-auc:0.716222
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [342]#011train-auc:1#011validation-auc:0.715697
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [343]#011train-auc:1#011validation-auc:0.720921
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [344]#011train-auc:1#011validation-auc:0.717114
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [345]#011train-auc:1#011validation-auc:0.712909
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [346]#011train-auc:1#011validation-auc:0.71138
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [347]#011train-auc:1#011validation-auc:0.711157
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [348]#011train-auc:1#011validation-auc:0.714008
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [349]#011train-auc:1#011validation-auc:0.713928
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [350]#011train-auc:1#011validation-auc:0.712367
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [351]#011train-auc:1#011validation-auc:0.711396
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [352]#011train-auc:1#011validation-auc:0.710201
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [353]#011train-auc:1#011validation-auc:0.711651
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [354]#011train-auc:1#011validation-auc:0.711236
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [355]#011train-auc:1#011validation-auc:0.71181
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [356]#011train-auc:1#011validation-auc:0.712017
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [357]#011train-auc:1#011validation-auc:0.71267
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [358]#011train-auc:1#011validation-auc:0.71369
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [359]#011train-auc:1#011validation-auc:0.709659
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [360]#011train-auc:1#011validation-auc:0.710328
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [361]#011train-auc:1#011validation-auc:0.711682
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [362]#011train-auc:1#011validation-auc:0.711252
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [363]#011train-auc:1#011validation-auc:0.71052
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [364]#011train-auc:1#011validation-auc:0.706458
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [365]#011train-auc:1#011validation-auc:0.706936
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [366]#011train-auc:1#011validation-auc:0.709006
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [367]#011train-auc:1#011validation-auc:0.703734
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [368]#011train-auc:1#011validation-auc:0.702284
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [369]#011train-auc:1#011validation-auc:0.703192
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [370]#011train-auc:1#011validation-auc:0.704259
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [371]#011train-auc:1#011validation-auc:0.698764
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [372]#011train-auc:1#011validation-auc:0.700898
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [373]#011train-auc:1#011validation-auc:0.703001
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [374]#011train-auc:1#011validation-auc:0.704817
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [375]#011train-auc:1#011validation-auc:0.705008
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [376]#011train-auc:1#011validation-auc:0.704419
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [377]#011train-auc:1#011validation-auc:0.704467
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [378]#011train-auc:1#011validation-auc:0.700341
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [379]#011train-auc:1#011validation-auc:0.700835
# [09:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [380]#011train-auc:1#011validation-auc:0.703559
# Billable seconds: 33
# INFO:sagemaker:Creating endpoint with name device-failure-detection-endpoint-2018-12-15-09-21-45
# ---------------------------------------------------------------!

# %%
sm_client.list_endpoints()
# Out:
# {'Endpoints': [{'EndpointName': 'device-failure-detection-endpoint-2018-12-15-09-21-45',
#    'EndpointArn': 'arn:aws:sagemaker:eu-west-1:362097852896:endpoint/device-failure-detection-endpoint-2018-12-15-09-21-45',
#    'CreationTime': datetime.datetime(2018, 12, 15, 9, 21, 46, 46000, tzinfo=tzlocal()),
#    'LastModifiedTime': datetime.datetime(2018, 12, 15, 9, 27, 4, 127000, tzinfo=tzlocal()),
#    'EndpointStatus': 'InService'}],
#  'ResponseMetadata': {'RequestId': '130b7fb6-f2ba-4102-b3f8-1bcc0e7270b7',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '130b7fb6-f2ba-4102-b3f8-1bcc0e7270b7',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '305',
#    'date': 'Sat, 15 Dec 2018 09:27:04 GMT'},
#   'RetryAttempts': 0}}

# %%
from sagemaker.predictor import csv_serializer

device_failure_predictor.content_type = 'text/csv'
device_failure_predictor.serializer = csv_serializer
device_failure_predictor.deserializer = None

# %% [markdown]
# Loading Test Data

# %%
test_data=pd.read_csv(test_data_s3_path)
test_data_X=test_data[np.setdiff1d(test_data.columns,['y', 'device', 'date'])].as_matrix()
test_data_Y=np.array(test_data['y'])

# %% [markdown]
# Lets predict a single test example!

# %%
device_failure_predictor.predict(test_data_X[10])
# Out:
# b'0.0314123667777'

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# Predicting failure probability for Test Dataset

# %%
def predict(data, rows=500):
    split_array = np.array_split(data, int(data.shape[0] / float(rows) + 1))
    predictions = ''
    for array in split_array:
        predictions = ','.join([predictions, device_failure_predictor.predict(array).decode('utf-8')])

    return np.fromstring(predictions[1:], sep=',')

predictions = predict(test_data_X)

# %% [markdown]
# Calculating Test Dataset Performance of the Best Model (Receiver Operating Curve Area Under Curve Score)

# %%
from sklearn.metrics import roc_curve, roc_auc_score, auc , confusion_matrix
#Compute ROC curve and area under the curve

fpr, tpr, thresholds = roc_curve(test_data_Y, predictions)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, lw=1, alpha=1,
             label='ROC (AUC = %0.2f)' % (roc_auc))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC Curve--AUC for testing sample is %.2f' % 
          (roc_auc_score(test_data_Y,predictions)))
plt.show()

# %%
#calculate other information on resulting predictions
test_data['preds']=predictions

roc_df=pd.DataFrame({'fpr':fpr,'tpr':tpr,'thresholds':thresholds})
roc_df['error_rate_for_positives']=roc_df.fpr
roc_df['error_rate_for_negatives']=0
roc_df['tp'],roc_df['tn'],roc_df['fp'],roc_df['fn']=0,0,0,0
roc_df['tp_device'],roc_df['tn_device'],roc_df['fp_device'],roc_df['fp_device']=0,0,0,0
roc_df['device_error_rate_for_positives'],roc_df['device_error_rate_for_negatives']=0,0

temp=test_data.copy()

for n in range(roc_df.shape[0]):
    i=roc_df.loc[n,'thresholds']
    preds_01 = predictions >=i#/10.0
    preds_01=preds_01 *1
    cnf_matrix = confusion_matrix(test_data_Y, preds_01)#.ravel()
    tn,fp,fn,tp = cnf_matrix.ravel()
    roc_df.loc[n,'tp']=tp
    roc_df.loc[n,'fp']=fp
    roc_df.loc[n,'tn']=tn
    roc_df.loc[n,'fn']=fn
    roc_df.loc[n,'error_rate_for_positives'] = fp/(fp+tn)
    roc_df.loc[n,'error_rate_for_negatives'] = fn/(fn+tp)
    
    temp.loc[:,'pred']=preds_01
    accuracy=temp.groupby('device')[['y','pred']].sum()
    accuracy.loc[:,'predicted']=accuracy.pred>0
    a=pd.crosstab(accuracy.y,accuracy.predicted)
    if a.shape[1]==1:
        a.loc[:,'True']=0
    tn_device,fp_device,fn_device,tp_device=a.values.ravel()
    roc_df.loc[n,'tp_device']=tp_device
    roc_df.loc[n,'fp_device']=fp_device
    roc_df.loc[n,'tn_device']=tn_device
    roc_df.loc[n,'fn_device']=fn_device
    roc_df['device_error_rate_for_positives']=fp_device/(tn_device+fp_device)
    roc_df['device_error_rate_for_negatives']=fn_device/(fn_device+tp_device)

# %% [markdown]
# We received Confirmation on a rule which states Detecting a Single Failure has benefit to compensate the Cost of Checking 200 Non-Failed Devices

# %%
roc_df.trade_off=roc_df.fp-200*roc_df.tp
fp_cross=0
for i in range(len(roc_df.trade_off)-4,-1,-1):
    current=roc_df.trade_off[i]
    next_one = roc_df.trade_off[i+1]
    next_two = roc_df.trade_off[i+2]
    next_three = roc_df.trade_off[i+3]
    if (current<=0 and next_one >0 and next_two>0 and next_three >0): 
        fp_cross=roc_df.fp[i]
        print('fp_cross is ',fp_cross)
        break
# Out:
# fp_cross is  942

# %% [markdown]
# ## Plotting a Confusion Matrix based on Cuttoff Threshold Calculated Above Via Cost-Benefit Analysis

# %%
th_cross=roc_df.loc[roc_df.fp==fp_cross,'thresholds'].values[0]
preds_01 = predictions >=0.1
preds_01=preds_01 *1
cnf_matrix = confusion_matrix(test_data_Y, preds_01)

ax=sns.heatmap(cnf_matrix,annot=True,fmt='d',cmap='YlGnBu')
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %% [markdown]
# ## Delete Endpoint (Just as a Cleanup)

# %%
sess.delete_endpoint(endpoint_name=device_failure_predictor.endpoint)

# %% [markdown]
# # Other Links

# %% [markdown]
# https://github.com/awslabs/amazon-sagemaker-examples <br/>
# <a href="https://www.youtube.com/watch?v=FKY3A9RasGw">AWS re:Invent 2018: Build & Deploy ML Models Quickly & Easily with Amazon SageMaker (AIM404)</a>
