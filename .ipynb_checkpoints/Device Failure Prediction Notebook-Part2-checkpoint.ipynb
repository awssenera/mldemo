# %%
import boto3
import pandas as pd
from sagemaker import get_execution_role
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  
import seaborn as sns
import sagemaker
from sagemaker.amazon.amazon_estimator import get_image_uri

# %% [markdown]
# # Model Tuning and Training
# Built-in Algorithms in Amazon SageMaker: https://docs.aws.amazon.com/sagemaker/latest/dg/algos.html

# %%
role = get_execution_role()

region = boto3.Session().region_name
bucket = 'ml-demo-device-failures'

sess = sagemaker.Session()
sm_client=sess.sagemaker_client

s3_input_train = boto3.Session().resource('s3').Bucket(bucket).Object('train/train.dat')
train_data_s3_path="s3://{}/{}".format(s3_input_train.bucket_name,s3_input_train.key)

s3_input_validation = boto3.Session().resource('s3').Bucket(bucket).Object('validation/validation.dat')
validation_data_s3_path="s3://{}/{}".format(s3_input_validation.bucket_name,s3_input_validation.key)

s3_input_test = boto3.Session().resource('s3').Bucket(bucket).Object('test/test.csv')
test_data_s3_path = 'https://s3-{}.amazonaws.com/{}/{}'.format(region,s3_input_test.bucket_name,s3_input_test.key)

# %% [markdown]
# About XGboost Algorithm: https://arxiv.org/pdf/1603.02754.pdf
# https://aws.amazon.com/sagemaker/pricing/instance-types/
#
# During Model Training it is recommendable to use a Compute Optimized (ml.c5 type) or Accelerated Computing Instance (ml.p3) depeding on the training scenario.

# %%
container = get_image_uri(region, 'xgboost')

xgb_estimator = sagemaker.estimator.Estimator(container,
                                    role, 
                                    train_instance_count=1, 
                                    train_instance_type='ml.c5.9xlarge',
                                    output_path='s3://{}/models/output'.format(bucket),
                                    sagemaker_session=sess,
                                    tags=[{"Key":"project","Value":"oxford_demo"}])

# %% [markdown]
# ## Model Hyperparameter Tuning
#
# Sagemaker Hyperparameter tuning uses an Amazon SageMaker implementation of Bayesian optimization.<br/>
# https://docs.aws.amazon.com/sagemaker/latest/dg/xgboost_hyperparameters.html<br/>

# %%
from sagemaker.tuner import HyperparameterTuner, ContinuousParameter, IntegerParameter

xgb_estimator.set_hyperparameters(seed=123,base_score=0.5,n_thread=4,rate_drop=0.2)

param_dist_xgb = {
              'subsample': ContinuousParameter(0.3, 0.8),
              'max_depth': IntegerParameter(3, 9),
              'colsample_bytree': ContinuousParameter(0.45, 0.5),
              'min_child_weight': IntegerParameter(1, 3),
              'num_round':  IntegerParameter(150, 500),
              'lambda':   ContinuousParameter(0.05, 0.4)
              }

# Configure Hyperparameter Tuner
xgb_tuner = HyperparameterTuner(estimator=xgb_estimator,  # previously-configured Estimator object
                               objective_metric_name='validation:auc',
                               hyperparameter_ranges=param_dist_xgb,
                               max_jobs=100,
                               max_parallel_jobs=10,
                               base_tuning_job_name='device-failure-detection-xgboost-',
                               tags=[{"Key":"project","Value":"oxford_demo"}],
                               early_stopping_type="Auto"
                               )

# %% [markdown]
# ## Model Training

# %%
xgb_tuner.fit(inputs={'train': train_data_s3_path, 'validation': validation_data_s3_path})
# Out:
# INFO:sagemaker:Creating hyperparameter tuning job with name: device-failure-detec-181215-0233

# %% [markdown]
# Checking Results of All Trained Models

# %%
xgb_tuner_analytics = xgb_tuner.analytics()
modelTuningOutputs=xgb_tuner_analytics.dataframe()
modelTuningOutputs.sort_values('FinalObjectiveValue',inplace=True, ascending=False)
modelTuningOutputs
# Out:
# 88             0.168897                        39.0 2018-12-15 02:39:06+00:00
# 0                   NaN                         NaN                       NaT
# 1                   NaN                         NaN                       NaT
# 2                   NaN                         NaN                       NaT
# 3                   NaN                         NaN                       NaT
# 4                   NaN                         NaN                       NaT
# 5                   NaN                         NaN                       NaT
# 6                   NaN                         NaN                       NaT
# 7                   NaN                         NaN                       NaT
# 8                   NaN                        47.0 2018-12-15 03:01:23+00:00
# 9                   NaN                        34.0 2018-12-15 03:01:19+00:00
#
#                                   TrainingJobName TrainingJobStatus  \
# 56  device-failure-detec-181215-0233-040-cd34225d         Completed
# 66  device-failure-detec-181215-0233-031-55fb42f5         Completed
# 82  device-failure-detec-181215-0233-017-42299de4           Stopped
# 64  device-failure-detec-181215-0233-033-9a26b826         Completed
# 83  device-failure-detec-181215-0233-016-fa3897a5         Completed
# 73  device-failure-detec-181215-0233-025-cb994e1c         Completed
# 43  device-failure-detec-181215-0233-052-08f68650         Completed
# 63  device-failure-detec-181215-0233-034-28ff9a94         Completed
# 35  device-failure-detec-181215-0233-058-3dae669f         Completed
# 40  device-failure-detec-181215-0233-055-fbe0e2c0         Completed
# 34  device-failure-detec-181215-0233-059-3a7de2b4         Completed
# 75  device-failure-detec-181215-0233-024-082830c2         Completed
# 28  device-failure-detec-181215-0233-065-82f88d40         Completed
# 15  device-failure-detec-181215-0233-074-f818ef1c         Completed
# 45  device-failure-detec-181215-0233-050-4610a438           Stopped
# 62  device-failure-detec-181215-0233-035-f4d5ad34         Completed
# 90  device-failure-detec-181215-0233-010-27bd48bb         Completed
# 80  device-failure-detec-181215-0233-019-1f9318cd         Completed
# 46  device-failure-detec-181215-0233-049-e35ddcc4         Completed
# 52  device-failure-detec-181215-0233-044-9de40bfe         Completed
# 10  device-failure-detec-181215-0233-079-d1eefda5           Stopped
# 92  device-failure-detec-181215-0233-008-f24fb008           Stopped
# 25  device-failure-detec-181215-0233-067-5b5b1a44         Completed
# 99  device-failure-detec-181215-0233-001-ae6506d5         Completed
# 38  device-failure-detec-181215-0233-057-b1ce37a9         Completed
# 36  device-failure-detec-181215-0233-058-11df9bfb         Completed
# 50  device-failure-detec-181215-0233-046-73f49834         Completed
# 48  device-failure-detec-181215-0233-048-b40ac5c0         Completed
# 53  device-failure-detec-181215-0233-043-39df8f23         Completed
# 98  device-failure-detec-181215-0233-002-8058df20         Completed
# ..                                            ...               ...
# 94  device-failure-detec-181215-0233-006-7ddbd7c3         Completed
# 13  device-failure-detec-181215-0233-076-f181b739         Completed
# 72  device-failure-detec-181215-0233-026-e19e6bf1           Stopped
# 87  device-failure-detec-181215-0233-012-ea030d48         Completed
# 77  device-failure-detec-181215-0233-022-c3bc68d6         Completed
# 16  device-failure-detec-181215-0233-074-722712db         Completed
# 69  device-failure-detec-181215-0233-028-9ac2e99d         Completed
# 42  device-failure-detec-181215-0233-053-b221a14d         Completed
# 39  device-failure-detec-181215-0233-056-dafbf44c         Completed
# 60  device-failure-detec-181215-0233-037-2b8715c8         Completed
# 11  device-failure-detec-181215-0233-078-e238fd30         Completed
# 79  device-failure-detec-181215-0233-020-7360e123         Completed
# 48               2.0      432.0   0.466320
# 53               1.0      447.0   0.513607
# 98               2.0      240.0   0.618774
# ..               ...        ...        ...
# 94               1.0      354.0   0.625006
# 13               1.0      415.0   0.367006
# 72               1.0      477.0   0.305818
# 87               2.0      473.0   0.404355
# 77               1.0      223.0   0.469489
# 16               1.0      412.0   0.362006
# 69               3.0      156.0   0.650891
# 42               2.0      459.0   0.770199
# 39               2.0      466.0   0.770199
# 60               1.0      475.0   0.661282
# 11               2.0      462.0   0.325934
# 79               1.0      386.0   0.469813
# 67               3.0      335.0   0.546505
# 65               1.0      483.0   0.793698
# 70               1.0      487.0   0.793698
# 76               1.0      386.0   0.463660
# 54               1.0      411.0   0.781623
# 97               1.0      259.0   0.588612
# 17               3.0      460.0   0.432563
# 88               2.0      319.0   0.467312
# 0                2.0      500.0   0.773744
# 1                2.0      500.0   0.778744
# 2                2.0      463.0   0.799988
# 3                2.0      500.0   0.768744
# 4                1.0      178.0   0.326926
# 5                2.0      444.0   0.515036
# 6                2.0      456.0   0.755266
# 7                2.0      473.0   0.307303
# 8                2.0      460.0   0.760266
# 9                1.0      474.0   0.482627
#
# [100 rows x 12 columns]

# %% [markdown]
# # Model Deployment to An Endpoint for Inference

# %%
endpoint_name = 'device-failure-detection-endpoint-' + strftime("%Y-%m-%d-%H-%M-%S", gmtime())
device_failure_predictor = xgb_tuner.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge',endpoint_name=endpoint_name)
# Out:
# INFO:sagemaker:Creating model with name: xgboost-2018-12-15-03-01-59-278
# 2018-12-15 02:47:47 Starting - Preparing the instances for training
# 2018-12-15 02:47:47 Downloading - Downloading input data
# 2018-12-15 02:47:47 Training - Training image download completed. Training in progress.
# 2018-12-15 02:47:47 Uploading - Uploading generated training model
# 2018-12-15 02:47:47 Completed - Training job completedArguments: train
# [2018-12-15:02:47:25:INFO] Running standalone xgboost training.
# [2018-12-15:02:47:25:INFO] Setting up HPO optimized metric to be : auc
# [2018-12-15:02:47:25:INFO] File size need to be processed in the node: 35.72mb. Available memory size in the node: 54783.59mb
# [02:47:25] S3DistributionType set as FullyReplicated
# [02:47:25] 87692x49 matrix with 2199997 entries loaded from /opt/ml/input/data/train
# [02:47:25] S3DistributionType set as FullyReplicated
# [02:47:25] 10469x49 matrix with 264441 entries loaded from /opt/ml/input/data/validation
# [02:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=7
# [0]#011train-auc:0.794245#011validation-auc:0.494457
# [02:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=7
# [1]#011train-auc:0.808066#011validation-auc:0.49417
# [02:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=7
# [2]#011train-auc:0.856595#011validation-auc:0.488818
# [02:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=7
# [3]#011train-auc:0.887457#011validation-auc:0.560674
# [02:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=7
# [4]#011train-auc:0.887771#011validation-auc:0.562968
# [02:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=7
# [5]#011train-auc:0.89993#011validation-auc:0.555816
# [02:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=7
# [6]#011train-auc:0.900747#011validation-auc:0.556214
# [02:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=7
# [7]#011train-auc:0.900964#011validation-auc:0.558508
# [02:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=7
# [8]#011train-auc:0.900975#011validation-auc:0.558508
# [02:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=7
# [9]#011train-auc:0.901063#011validation-auc:0.558508
# [02:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=7
# [10]#011train-auc:0.901197#011validation-auc:0.558508
# [02:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=7
# [11]#011train-auc:0.922769#011validation-auc:0.559384
# [02:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=7
# [12]#011train-auc:0.923281#011validation-auc:0.561773
# [02:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=7
# [13]#011train-auc:0.923442#011validation-auc:0.561773
# [02:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=7
# [14]#011train-auc:0.930651#011validation-auc:0.632331
# [02:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=7
# [15]#011train-auc:0.930674#011validation-auc:0.632331
# [02:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=7
# [16]#011train-auc:0.929985#011validation-auc:0.625816
# [02:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=7
# [17]#011train-auc:0.930307#011validation-auc:0.627784
# [02:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=7
# [18]#011train-auc:0.930801#011validation-auc:0.630189
# [02:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=7
# [19]#011train-auc:0.930866#011validation-auc:0.630189
# [02:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=7
# [20]#011train-auc:0.931362#011validation-auc:0.631049
# [02:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=7
# [21]#011train-auc:0.931383#011validation-auc:0.631527
# [02:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=7
# [22]#011train-auc:0.930814#011validation-auc:0.630125
# [02:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=7
# [23]#011train-auc:0.941897#011validation-auc:0.621316
# [02:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=7
# [24]#011train-auc:0.947027#011validation-auc:0.625299
# [02:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=7
# [25]#011train-auc:0.947506#011validation-auc:0.484206
# [02:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=7
# [26]#011train-auc:0.947534#011validation-auc:0.483489
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=7
# [27]#011train-auc:0.947597#011validation-auc:0.484381
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=7
# [28]#011train-auc:0.953998#011validation-auc:0.447983
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=7
# [29]#011train-auc:0.956437#011validation-auc:0.408519
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=7
# [30]#011train-auc:0.956713#011validation-auc:0.407898
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=7
# [31]#011train-auc:0.980535#011validation-auc:0.367812
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=7
# [32]#011train-auc:0.988544#011validation-auc:0.510617
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=7
# [33]#011train-auc:0.986866#011validation-auc:0.648205
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=7
# [34]#011train-auc:0.986949#011validation-auc:0.648205
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=7
# [35]#011train-auc:0.987582#011validation-auc:0.665249
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=7
# [36]#011train-auc:0.987781#011validation-auc:0.666906
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=7
# [37]#011train-auc:0.988613#011validation-auc:0.702228
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=7
# [38]#011train-auc:0.995635#011validation-auc:0.696518
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=7
# [39]#011train-auc:0.995384#011validation-auc:0.769139
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=7
# [40]#011train-auc:0.995411#011validation-auc:0.768326
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=7
# [41]#011train-auc:0.995546#011validation-auc:0.785705
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=7
# [42]#011train-auc:0.99614#011validation-auc:0.730455
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=7
# [43]#011train-auc:0.996282#011validation-auc:0.730853
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=7
# [44]#011train-auc:0.996449#011validation-auc:0.737966
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=7
# [45]#011train-auc:0.996686#011validation-auc:0.734238
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=7
# [46]#011train-auc:0.997199#011validation-auc:0.726114
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=7
# [47]#011train-auc:0.997423#011validation-auc:0.72715
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=7
# [48]#011train-auc:0.997547#011validation-auc:0.738085
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=7
# [49]#011train-auc:0.998914#011validation-auc:0.735066
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=7
# [50]#011train-auc:0.998855#011validation-auc:0.736038
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=7
# [51]#011train-auc:0.998853#011validation-auc:0.740745
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 0 pruned nodes, max_depth=7
# [52]#011train-auc:0.998873#011validation-auc:0.564274
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=7
# [53]#011train-auc:0.998798#011validation-auc:0.558986
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=7
# [54]#011train-auc:0.998847#011validation-auc:0.576571
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=7
# [55]#011train-auc:0.998989#011validation-auc:0.586941
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=7
# [56]#011train-auc:0.999#011validation-auc:0.566122
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=7
# [57]#011train-auc:0.99969#011validation-auc:0.559081
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=7
# [58]#011train-auc:1#011validation-auc:0.565341
# [02:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=7
# [59]#011train-auc:1#011validation-auc:0.474051
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=7
# [60]#011train-auc:1#011validation-auc:0.490028
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=7
# [61]#011train-auc:1#011validation-auc:0.489646
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=7
# [62]#011train-auc:1#011validation-auc:0.50861
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=7
# [63]#011train-auc:1#011validation-auc:0.508705
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=7
# [64]#011train-auc:1#011validation-auc:0.509024
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=7
# [65]#011train-auc:1#011validation-auc:0.508291
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=7
# [66]#011train-auc:1#011validation-auc:0.49816
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=7
# [67]#011train-auc:1#011validation-auc:0.504054
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 0 pruned nodes, max_depth=7
# [68]#011train-auc:1#011validation-auc:0.502811
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 0 pruned nodes, max_depth=7
# [69]#011train-auc:1#011validation-auc:0.491741
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=7
# [70]#011train-auc:1#011validation-auc:0.495771
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 0 pruned nodes, max_depth=7
# [71]#011train-auc:1#011validation-auc:0.498797
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=7
# [72]#011train-auc:1#011validation-auc:0.496504
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=7
# [73]#011train-auc:1#011validation-auc:0.494672
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=7
# [74]#011train-auc:1#011validation-auc:0.492346
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=7
# [75]#011train-auc:1#011validation-auc:0.477691
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=7
# [76]#011train-auc:1#011validation-auc:0.477628
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=7
# [77]#011train-auc:1#011validation-auc:0.47981
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=7
# [78]#011train-auc:1#011validation-auc:0.476624
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=7
# [79]#011train-auc:1#011validation-auc:0.480112
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=7
# [80]#011train-auc:1#011validation-auc:0.48067
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=7
# [81]#011train-auc:1#011validation-auc:0.481371
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=7
# [82]#011train-auc:1#011validation-auc:0.48196
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=7
# [83]#011train-auc:1#011validation-auc:0.486373
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=7
# [84]#011train-auc:1#011validation-auc:0.473741
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=7
# [85]#011train-auc:1#011validation-auc:0.455916
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=7
# [86]#011train-auc:1#011validation-auc:0.455566
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=7
# [87]#011train-auc:1#011validation-auc:0.451663
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=7
# [88]#011train-auc:1#011validation-auc:0.45289
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=7
# [89]#011train-auc:1#011validation-auc:0.444638
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=7
# [90]#011train-auc:1#011validation-auc:0.445371
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=7
# [91]#011train-auc:1#011validation-auc:0.441883
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=7
# [92]#011train-auc:1#011validation-auc:0.459596
# [02:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=7
# [93]#011train-auc:1#011validation-auc:0.460249
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=7
# [94]#011train-auc:1#011validation-auc:0.460583
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=7
# [95]#011train-auc:1#011validation-auc:0.457557
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=7
# [96]#011train-auc:1#011validation-auc:0.456808
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 0 pruned nodes, max_depth=7
# [97]#011train-auc:1#011validation-auc:0.453734
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=7
# [98]#011train-auc:1#011validation-auc:0.45539
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=7
# [99]#011train-auc:1#011validation-auc:0.471845
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=7
# [100]#011train-auc:1#011validation-auc:0.478679
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=7
# [101]#011train-auc:1#011validation-auc:0.492282
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=7
# [102]#011train-auc:1#011validation-auc:0.503512
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=7
# [103]#011train-auc:1#011validation-auc:0.508164
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=7
# [104]#011train-auc:1#011validation-auc:0.508801
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=7
# [105]#011train-auc:1#011validation-auc:0.505392
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=7
# [106]#011train-auc:1#011validation-auc:0.506698
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=7
# [107]#011train-auc:1#011validation-auc:0.515889
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=7
# [108]#011train-auc:1#011validation-auc:0.513659
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=7
# [109]#011train-auc:1#011validation-auc:0.509247
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 0 pruned nodes, max_depth=7
# [110]#011train-auc:1#011validation-auc:0.511748
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=7
# [111]#011train-auc:1#011validation-auc:0.510011
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=7
# [112]#011train-auc:1#011validation-auc:0.508833
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=7
# [113]#011train-auc:1#011validation-auc:0.505137
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=7
# [114]#011train-auc:1#011validation-auc:0.504245
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=7
# [115]#011train-auc:1#011validation-auc:0.501888
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=7
# [116]#011train-auc:1#011validation-auc:0.49781
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=7
# [117]#011train-auc:1#011validation-auc:0.497666
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 0 pruned nodes, max_depth=7
# [118]#011train-auc:1#011validation-auc:0.498096
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=7
# [119]#011train-auc:1#011validation-auc:0.498383
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=7
# [120]#011train-auc:1#011validation-auc:0.498861
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=7
# [121]#011train-auc:1#011validation-auc:0.499642
# [02:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=7
# [122]#011train-auc:1#011validation-auc:0.499052
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=7
# [123]#011train-auc:1#011validation-auc:0.500167
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 0 pruned nodes, max_depth=7
# [124]#011train-auc:1#011validation-auc:0.502477
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=7
# [125]#011train-auc:1#011validation-auc:0.499673
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=7
# [126]#011train-auc:1#011validation-auc:0.498256
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=7
# [127]#011train-auc:1#011validation-auc:0.508403
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=7
# [128]#011train-auc:1#011validation-auc:0.509741
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=7
# [129]#011train-auc:1#011validation-auc:0.502047
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=7
# [130]#011train-auc:1#011validation-auc:0.499371
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=7
# [131]#011train-auc:1#011validation-auc:0.500056
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=7
# [132]#011train-auc:1#011validation-auc:0.499116
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=7
# [133]#011train-auc:1#011validation-auc:0.657547
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=7
# [134]#011train-auc:1#011validation-auc:0.65871
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=7
# [135]#011train-auc:1#011validation-auc:0.660128
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=7
# [136]#011train-auc:1#011validation-auc:0.659889
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=7
# [137]#011train-auc:1#011validation-auc:0.65425
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=7
# [138]#011train-auc:1#011validation-auc:0.647878
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=7
# [139]#011train-auc:1#011validation-auc:0.643163
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=7
# [140]#011train-auc:1#011validation-auc:0.640471
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=7
# [141]#011train-auc:1#011validation-auc:0.641061
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=7
# [142]#011train-auc:1#011validation-auc:0.658583
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=7
# [143]#011train-auc:1#011validation-auc:0.658025
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=7
# [144]#011train-auc:1#011validation-auc:0.657245
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=7
# [145]#011train-auc:1#011validation-auc:0.657515
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=7
# [146]#011train-auc:1#011validation-auc:0.657531
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=7
# [147]#011train-auc:1#011validation-auc:0.654075
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=7
# [148]#011train-auc:1#011validation-auc:0.654091
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=7
# [149]#011train-auc:1#011validation-auc:0.651128
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=7
# [150]#011train-auc:1#011validation-auc:0.652131
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=7
# [151]#011train-auc:1#011validation-auc:0.649758
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 0 pruned nodes, max_depth=7
# [152]#011train-auc:1#011validation-auc:0.647767
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=7
# [153]#011train-auc:1#011validation-auc:0.649726
# [02:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=7
# [154]#011train-auc:1#011validation-auc:0.647002
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=7
# [155]#011train-auc:1#011validation-auc:0.648444
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=7
# [156]#011train-auc:1#011validation-auc:0.676654
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 0 pruned nodes, max_depth=7
# [157]#011train-auc:1#011validation-auc:0.679553
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=7
# [158]#011train-auc:1#011validation-auc:0.683058
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=7
# [159]#011train-auc:1#011validation-auc:0.694352
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=7
# [160]#011train-auc:1#011validation-auc:0.696805
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=7
# [161]#011train-auc:1#011validation-auc:0.697776
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=7
# [162]#011train-auc:1#011validation-auc:0.696199
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=7
# [163]#011train-auc:1#011validation-auc:0.69604
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 0 pruned nodes, max_depth=7
# [164]#011train-auc:1#011validation-auc:0.701727
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=7
# [165]#011train-auc:1#011validation-auc:0.699497
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 0 pruned nodes, max_depth=7
# [166]#011train-auc:1#011validation-auc:0.698907
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=7
# [167]#011train-auc:1#011validation-auc:0.697235
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=7
# [168]#011train-auc:1#011validation-auc:0.697044
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=7
# [169]#011train-auc:1#011validation-auc:0.696518
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 0 pruned nodes, max_depth=7
# [170]#011train-auc:1#011validation-auc:0.707557
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=7
# [171]#011train-auc:1#011validation-auc:0.713355
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 0 pruned nodes, max_depth=7
# [172]#011train-auc:1#011validation-auc:0.712065
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=7
# [173]#011train-auc:1#011validation-auc:0.7059
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=7
# [174]#011train-auc:1#011validation-auc:0.7077
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=7
# [175]#011train-auc:1#011validation-auc:0.707413
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=7
# [176]#011train-auc:1#011validation-auc:0.701376
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=7
# [177]#011train-auc:1#011validation-auc:0.698652
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=7
# [178]#011train-auc:1#011validation-auc:0.698541
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=7
# [179]#011train-auc:1#011validation-auc:0.700166
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 0 pruned nodes, max_depth=7
# [180]#011train-auc:1#011validation-auc:0.698111
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=7
# [181]#011train-auc:1#011validation-auc:0.695244
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=7
# [182]#011train-auc:1#011validation-auc:0.692918
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=7
# [183]#011train-auc:1#011validation-auc:0.683265
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=7
# [184]#011train-auc:1#011validation-auc:0.68567
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=7
# [185]#011train-auc:1#011validation-auc:0.680302
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 0 pruned nodes, max_depth=7
# [186]#011train-auc:1#011validation-auc:0.679999
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=7
# [187]#011train-auc:1#011validation-auc:0.677005
# [02:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=7
# [188]#011train-auc:1#011validation-auc:0.674137
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=7
# [189]#011train-auc:1#011validation-auc:0.673198
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=7
# [190]#011train-auc:1#011validation-auc:0.670649
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 0 pruned nodes, max_depth=7
# [191]#011train-auc:1#011validation-auc:0.665711
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=7
# [192]#011train-auc:1#011validation-auc:0.662955
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=7
# [193]#011train-auc:1#011validation-auc:0.662939
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=7
# [194]#011train-auc:1#011validation-auc:0.666667
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=7
# [195]#011train-auc:1#011validation-auc:0.663927
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=7
# [196]#011train-auc:1#011validation-auc:0.668291
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=7
# [197]#011train-auc:1#011validation-auc:0.671254
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=7
# [198]#011train-auc:1#011validation-auc:0.668865
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 0 pruned nodes, max_depth=7
# [199]#011train-auc:1#011validation-auc:0.667479
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=7
# [200]#011train-auc:1#011validation-auc:0.673962
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=7
# [201]#011train-auc:1#011validation-auc:0.678566
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=7
# [202]#011train-auc:1#011validation-auc:0.676718
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=7
# [203]#011train-auc:1#011validation-auc:0.688999
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 0 pruned nodes, max_depth=7
# [204]#011train-auc:1#011validation-auc:0.666969
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=7
# [205]#011train-auc:1#011validation-auc:0.669454
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=7
# [206]#011train-auc:1#011validation-auc:0.665552
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 0 pruned nodes, max_depth=7
# [207]#011train-auc:1#011validation-auc:0.659483
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=7
# [208]#011train-auc:1#011validation-auc:0.660327
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=7
# [209]#011train-auc:1#011validation-auc:0.659785
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=7
# [210]#011train-auc:1#011validation-auc:0.657507
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=7
# [211]#011train-auc:1#011validation-auc:0.656775
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=7
# [212]#011train-auc:1#011validation-auc:0.659737
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=7
# [213]#011train-auc:1#011validation-auc:0.658925
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 0 pruned nodes, max_depth=7
# [214]#011train-auc:1#011validation-auc:0.661999
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=7
# [215]#011train-auc:1#011validation-auc:0.661729
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=7
# [216]#011train-auc:1#011validation-auc:0.65883
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 0 pruned nodes, max_depth=7
# [217]#011train-auc:1#011validation-auc:0.660295
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=7
# [218]#011train-auc:1#011validation-auc:0.664118
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 0 pruned nodes, max_depth=7
# [219]#011train-auc:1#011validation-auc:0.664596
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=7
# [220]#011train-auc:1#011validation-auc:0.665074
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=7
# [221]#011train-auc:1#011validation-auc:0.669391
# [02:47:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 0 pruned nodes, max_depth=7
# [222]#011train-auc:1#011validation-auc:0.667304
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=7
# [223]#011train-auc:1#011validation-auc:0.667686
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 0 pruned nodes, max_depth=7
# [224]#011train-auc:1#011validation-auc:0.664803
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=7
# [225]#011train-auc:1#011validation-auc:0.673835
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=7
# [226]#011train-auc:1#011validation-auc:0.698589
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=7
# [227]#011train-auc:1#011validation-auc:0.702125
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=7
# [228]#011train-auc:1#011validation-auc:0.717481
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=7
# [229]#011train-auc:1#011validation-auc:0.716493
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=7
# [230]#011train-auc:1#011validation-auc:0.715617
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=7
# [231]#011train-auc:1#011validation-auc:0.714805
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=7
# [232]#011train-auc:1#011validation-auc:0.71498
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=7
# [233]#011train-auc:1#011validation-auc:0.727006
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=7
# [234]#011train-auc:1#011validation-auc:0.726098
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=7
# [235]#011train-auc:1#011validation-auc:0.724872
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=7
# [236]#011train-auc:1#011validation-auc:0.724983
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=7
# [237]#011train-auc:1#011validation-auc:0.724872
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=7
# [238]#011train-auc:1#011validation-auc:0.722052
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=7
# [239]#011train-auc:1#011validation-auc:0.724346
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 0 pruned nodes, max_depth=7
# [240]#011train-auc:1#011validation-auc:0.73016
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=7
# [241]#011train-auc:1#011validation-auc:0.735321
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=7
# [242]#011train-auc:1#011validation-auc:0.732024
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=7
# [243]#011train-auc:1#011validation-auc:0.729539
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 0 pruned nodes, max_depth=7
# [244]#011train-auc:1#011validation-auc:0.729475
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=7
# [245]#011train-auc:1#011validation-auc:0.732725
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=7
# [246]#011train-auc:1#011validation-auc:0.730447
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=7
# [247]#011train-auc:1#011validation-auc:0.738427
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=7
# [248]#011train-auc:1#011validation-auc:0.739781
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=7
# [249]#011train-auc:1#011validation-auc:0.742171
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=7
# [250]#011train-auc:1#011validation-auc:0.741438
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=7
# [251]#011train-auc:1#011validation-auc:0.74781
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=7
# [252]#011train-auc:1#011validation-auc:0.75047
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 0 pruned nodes, max_depth=7
# [253]#011train-auc:1#011validation-auc:0.749689
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=7
# [254]#011train-auc:1#011validation-auc:0.751378
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=7
# [255]#011train-auc:1#011validation-auc:0.742888
# [02:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 0 pruned nodes, max_depth=7
# [256]#011train-auc:1#011validation-auc:0.745978
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=7
# [257]#011train-auc:1#011validation-auc:0.747778
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=7
# [258]#011train-auc:1#011validation-auc:0.747348
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 0 pruned nodes, max_depth=7
# [259]#011train-auc:1#011validation-auc:0.736548
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 0 pruned nodes, max_depth=7
# [260]#011train-auc:1#011validation-auc:0.737217
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=7
# [261]#011train-auc:1#011validation-auc:0.736946
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 0 pruned nodes, max_depth=7
# [262]#011train-auc:1#011validation-auc:0.73873
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=7
# [263]#011train-auc:1#011validation-auc:0.73701
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 0 pruned nodes, max_depth=7
# [264]#011train-auc:1#011validation-auc:0.734095
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 0 pruned nodes, max_depth=7
# [265]#011train-auc:1#011validation-auc:0.733872
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=7
# [266]#011train-auc:1#011validation-auc:0.733043
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 0 pruned nodes, max_depth=7
# [267]#011train-auc:1#011validation-auc:0.735497
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=7
# [268]#011train-auc:1#011validation-auc:0.733585
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=7
# [269]#011train-auc:1#011validation-auc:0.732295
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=7
# [270]#011train-auc:1#011validation-auc:0.734413
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 0 pruned nodes, max_depth=7
# [271]#011train-auc:1#011validation-auc:0.735305
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=7
# [272]#011train-auc:1#011validation-auc:0.740355
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=7
# [273]#011train-auc:1#011validation-auc:0.740227
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=7
# [274]#011train-auc:1#011validation-auc:0.733935
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=7
# [275]#011train-auc:1#011validation-auc:0.734366
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=7
# [276]#011train-auc:1#011validation-auc:0.751792
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=7
# [277]#011train-auc:1#011validation-auc:0.754834
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=7
# [278]#011train-auc:1#011validation-auc:0.755376
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 0 pruned nodes, max_depth=7
# [279]#011train-auc:1#011validation-auc:0.749036
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=7
# [280]#011train-auc:1#011validation-auc:0.748973
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 0 pruned nodes, max_depth=7
# [281]#011train-auc:1#011validation-auc:0.748527
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=7
# [282]#011train-auc:1#011validation-auc:0.749642
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=7
# [283]#011train-auc:1#011validation-auc:0.748351
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=7
# [284]#011train-auc:1#011validation-auc:0.74652
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=7
# [285]#011train-auc:1#011validation-auc:0.74652
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=7
# [286]#011train-auc:1#011validation-auc:0.746153
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=7
# [287]#011train-auc:1#011validation-auc:0.754707
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=7
# [288]#011train-auc:1#011validation-auc:0.755265
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=7
# [289]#011train-auc:1#011validation-auc:0.752716
# [02:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=7
# [290]#011train-auc:1#011validation-auc:0.75399
# ...
# [305]#011train-auc:1#011validation-auc:0.782328
# [02:47:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=7
# [306]#011train-auc:1#011validation-auc:0.767387
# [02:47:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=7
# [307]#011train-auc:1#011validation-auc:0.763388
# [02:47:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=7
# [308]#011train-auc:1#011validation-auc:0.762289
# [02:47:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=7
# [309]#011train-auc:1#011validation-auc:0.765619
# [02:47:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=7
# [310]#011train-auc:1#011validation-auc:0.766431
# [02:47:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=7
# [311]#011train-auc:1#011validation-auc:0.763755
# [02:47:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=7
# [312]#011train-auc:1#011validation-auc:0.764535
# [02:47:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=7
# [313]#011train-auc:1#011validation-auc:0.764599
# [02:47:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=7
# [314]#011train-auc:1#011validation-auc:0.762337
# [02:47:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=7
# [315]#011train-auc:1#011validation-auc:0.762242
# [02:47:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=7
# [316]#011train-auc:1#011validation-auc:0.763532
# [02:47:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=7
# [317]#011train-auc:1#011validation-auc:0.76538
# [02:47:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=7
# [318]#011train-auc:1#011validation-auc:0.764137
# [02:47:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=7
# [319]#011train-auc:1#011validation-auc:0.764981
# [02:47:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=7
# [320]#011train-auc:1#011validation-auc:0.765332
# [02:47:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 0 pruned nodes, max_depth=7
# [321]#011train-auc:1#011validation-auc:0.765268
# [02:47:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 0 pruned nodes, max_depth=7
# [322]#011train-auc:1#011validation-auc:0.758068
# [02:47:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=7
# [323]#011train-auc:1#011validation-auc:0.757925
# [02:47:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=7
# [324]#011train-auc:1#011validation-auc:0.758928
# [02:47:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=7
# [325]#011train-auc:1#011validation-auc:0.754293
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=7
# [326]#011train-auc:1#011validation-auc:0.761684
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=7
# [327]#011train-auc:1#011validation-auc:0.757988
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=7
# [328]#011train-auc:1#011validation-auc:0.753289
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 0 pruned nodes, max_depth=7
# [329]#011train-auc:1#011validation-auc:0.741629
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=7
# [330]#011train-auc:1#011validation-auc:0.744942
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=7
# [331]#011train-auc:1#011validation-auc:0.744242
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=7
# [332]#011train-auc:1#011validation-auc:0.749036
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=7
# [333]#011train-auc:1#011validation-auc:0.74918
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=7
# [334]#011train-auc:1#011validation-auc:0.74558
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=7
# [335]#011train-auc:1#011validation-auc:0.748654
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 0 pruned nodes, max_depth=7
# [336]#011train-auc:1#011validation-auc:0.748272
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=7
# [337]#011train-auc:1#011validation-auc:0.75141
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=7
# [338]#011train-auc:1#011validation-auc:0.760203
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 0 pruned nodes, max_depth=7
# [339]#011train-auc:1#011validation-auc:0.760394
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=7
# [340]#011train-auc:1#011validation-auc:0.763181
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=7
# [341]#011train-auc:1#011validation-auc:0.763627
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=7
# [342]#011train-auc:1#011validation-auc:0.763341
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=7
# [343]#011train-auc:1#011validation-auc:0.765634
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=7
# [344]#011train-auc:1#011validation-auc:0.765141
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=7
# [345]#011train-auc:1#011validation-auc:0.764551
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=7
# [346]#011train-auc:1#011validation-auc:0.764647
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [347]#011train-auc:1#011validation-auc:0.764647
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=7
# [348]#011train-auc:1#011validation-auc:0.765571
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=7
# [349]#011train-auc:1#011validation-auc:0.765698
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [350]#011train-auc:1#011validation-auc:0.765029
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 0 pruned nodes, max_depth=7
# [351]#011train-auc:1#011validation-auc:0.762656
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=7
# [352]#011train-auc:1#011validation-auc:0.762512
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=7
# [353]#011train-auc:1#011validation-auc:0.763404
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=7
# [354]#011train-auc:1#011validation-auc:0.763404
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=7
# [355]#011train-auc:1#011validation-auc:0.762799
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=7
# [356]#011train-auc:1#011validation-auc:0.762799
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=7
# [357]#011train-auc:1#011validation-auc:0.762003
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=7
# [358]#011train-auc:1#011validation-auc:0.763293
# [02:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=7
# [359]#011train-auc:1#011validation-auc:0.76127
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=7
# [360]#011train-auc:1#011validation-auc:0.761923
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=7
# [361]#011train-auc:1#011validation-auc:0.771751
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=7
# [362]#011train-auc:1#011validation-auc:0.771767
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [363]#011train-auc:1#011validation-auc:0.771767
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=7
# [364]#011train-auc:1#011validation-auc:0.771831
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=7
# [365]#011train-auc:1#011validation-auc:0.769888
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=7
# [366]#011train-auc:1#011validation-auc:0.774491
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=7
# [367]#011train-auc:1#011validation-auc:0.773934
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=7
# [368]#011train-auc:1#011validation-auc:0.773822
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=7
# [369]#011train-auc:1#011validation-auc:0.774061
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=7
# [370]#011train-auc:1#011validation-auc:0.774045
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=7
# [371]#011train-auc:1#011validation-auc:0.77387
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 0 pruned nodes, max_depth=7
# [372]#011train-auc:1#011validation-auc:0.77473
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=7
# [373]#011train-auc:1#011validation-auc:0.77524
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 0 pruned nodes, max_depth=7
# [374]#011train-auc:1#011validation-auc:0.777279
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [375]#011train-auc:1#011validation-auc:0.777279
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [376]#011train-auc:1#011validation-auc:0.777279
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=7
# [377]#011train-auc:1#011validation-auc:0.78381
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [378]#011train-auc:1#011validation-auc:0.78381
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [379]#011train-auc:1#011validation-auc:0.78381
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 0 pruned nodes, max_depth=7
# [380]#011train-auc:1#011validation-auc:0.78596
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=7
# [381]#011train-auc:1#011validation-auc:0.794211
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [382]#011train-auc:1#011validation-auc:0.794211
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=7
# [383]#011train-auc:1#011validation-auc:0.798018
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [384]#011train-auc:1#011validation-auc:0.798018
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=7
# [385]#011train-auc:1#011validation-auc:0.794164
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=7
# [386]#011train-auc:1#011validation-auc:0.794243
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [387]#011train-auc:1#011validation-auc:0.794243
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [388]#011train-auc:1#011validation-auc:0.794323
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [389]#011train-auc:1#011validation-auc:0.794323
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=7
# [390]#011train-auc:1#011validation-auc:0.791822
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [391]#011train-auc:1#011validation-auc:0.791822
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [392]#011train-auc:1#011validation-auc:0.791822
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=7
# [393]#011train-auc:1#011validation-auc:0.791854
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=7
# [394]#011train-auc:1#011validation-auc:0.793702
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [395]#011train-auc:1#011validation-auc:0.793702
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [396]#011train-auc:1#011validation-auc:0.793702
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [397]#011train-auc:1#011validation-auc:0.793765
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [398]#011train-auc:1#011validation-auc:0.793765
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=7
# [399]#011train-auc:1#011validation-auc:0.792762
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [400]#011train-auc:1#011validation-auc:0.792762
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=7
# [401]#011train-auc:1#011validation-auc:0.791679
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [402]#011train-auc:1#011validation-auc:0.791679
# [02:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=7
# [403]#011train-auc:1#011validation-auc:0.791679
# Billable seconds: 42
# INFO:sagemaker:Creating endpoint with name device-failure-detection-endpoint-2018-12-15-03-01-58
# --------------------------------------------------------------!

# %%
sm_client.list_endpoints()
# Out:
# {'Endpoints': [{'EndpointName': 'device-failure-detection-endpoint-2018-12-15-03-01-58',
#    'EndpointArn': 'arn:aws:sagemaker:eu-west-1:362097852896:endpoint/device-failure-detection-endpoint-2018-12-15-03-01-58',
#    'CreationTime': datetime.datetime(2018, 12, 15, 3, 1, 59, 892000, tzinfo=tzlocal()),
#    'LastModifiedTime': datetime.datetime(2018, 12, 15, 3, 7, 9, 157000, tzinfo=tzlocal()),
#    'EndpointStatus': 'InService'}],
#  'ResponseMetadata': {'RequestId': 'a0aa18d9-ff95-4159-bbcc-666ff7a261b5',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'a0aa18d9-ff95-4159-bbcc-666ff7a261b5',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '305',
#    'date': 'Sat, 15 Dec 2018 03:07:12 GMT'},
#   'RetryAttempts': 0}}

# %%
from sagemaker.predictor import csv_serializer

device_failure_predictor.content_type = 'text/csv'
device_failure_predictor.serializer = csv_serializer
device_failure_predictor.deserializer = None

# %% [markdown]
# Loading Test Data

# %%
test_data=pd.read_csv(test_data_s3_path)
test_data_X=test_data[np.setdiff1d(test_data.columns,['y', 'device', 'date'])].as_matrix()
test_data_Y=np.array(test_data['y'])

# %% [markdown]
# Lets predict a single test example!

# %%
device_failure_predictor.predict(test_data_X[0])
# Out:
# b'0.233994930983'

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# Predicting failure probability for Test Dataset

# %%
def predict(data, rows=500):
    split_array = np.array_split(data, int(data.shape[0] / float(rows) + 1))
    predictions = ''
    for array in split_array:
        predictions = ','.join([predictions, device_failure_predictor.predict(array).decode('utf-8')])

    return np.fromstring(predictions[1:], sep=',')

predictions = predict(test_data_X)

# %% [markdown]
# Calculating Test Dataset Performance of the Best Model (Receiver Operating Curve Area Under Curve Score)

# %%
from sklearn.metrics import roc_curve, roc_auc_score, auc , confusion_matrix
#Compute ROC curve and area under the curve

fpr, tpr, thresholds = roc_curve(test_data_Y, predictions)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, lw=1, alpha=1,
             label='ROC (AUC = %0.2f)' % (roc_auc))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC Curve--AUC for testing sample is %.2f' % 
          (roc_auc_score(test_data_Y,predictions)))
plt.show()

# %%
#calculate other information on resulting predictions
test_data['preds']=predictions

roc_df=pd.DataFrame({'fpr':fpr,'tpr':tpr,'thresholds':thresholds})
roc_df['error_rate_for_positives']=roc_df.fpr
roc_df['error_rate_for_negatives']=0
roc_df['tp'],roc_df['tn'],roc_df['fp'],roc_df['fn']=0,0,0,0
roc_df['tp_device'],roc_df['tn_device'],roc_df['fp_device'],roc_df['fp_device']=0,0,0,0
roc_df['device_error_rate_for_positives'],roc_df['device_error_rate_for_negatives']=0,0

temp=test_data.copy()

for n in range(roc_df.shape[0]):
    i=roc_df.loc[n,'thresholds']
    preds_01 = predictions >=i#/10.0
    preds_01=preds_01 *1
    cnf_matrix = confusion_matrix(test_data_Y, preds_01)#.ravel()
    tn,fp,fn,tp = cnf_matrix.ravel()
    roc_df.loc[n,'tp']=tp
    roc_df.loc[n,'fp']=fp
    roc_df.loc[n,'tn']=tn
    roc_df.loc[n,'fn']=fn
    roc_df.loc[n,'error_rate_for_positives'] = fp/(fp+tn)
    roc_df.loc[n,'error_rate_for_negatives'] = fn/(fn+tp)
    
    temp.loc[:,'pred']=preds_01
    accuracy=temp.groupby('device')[['y','pred']].sum()
    accuracy.loc[:,'predicted']=accuracy.pred>0
    a=pd.crosstab(accuracy.y,accuracy.predicted)
    if a.shape[1]==1:
        a.loc[:,'True']=0
    tn_device,fp_device,fn_device,tp_device=a.values.ravel()
    roc_df.loc[n,'tp_device']=tp_device
    roc_df.loc[n,'fp_device']=fp_device
    roc_df.loc[n,'tn_device']=tn_device
    roc_df.loc[n,'fn_device']=fn_device
    roc_df['device_error_rate_for_positives']=fp_device/(tn_device+fp_device)
    roc_df['device_error_rate_for_negatives']=fn_device/(fn_device+tp_device)

# %% [markdown]
# We received Confirmation on a rule which states Detecting a Single Failure has benefit to compensate the Cost of Checking 100 Non-Failed Devices

# %%
roc_df.trade_off=roc_df.fp-100*roc_df.tp
fp_cross=0
for i in range(len(roc_df.trade_off)-4,-1,-1):
    current=roc_df.trade_off[i]
    next_one = roc_df.trade_off[i+1]
    next_two = roc_df.trade_off[i+2]
    next_three = roc_df.trade_off[i+3]
    if (current<=0 and next_one >0 and next_two>0 and next_three >0): 
        fp_cross=roc_df.fp[i]
        print('fp_cross is ',fp_cross)
        break
# Out:
# fp_cross is  383

# %% [markdown]
# ## Plotting a Confusion Matrix based on 0.72 Cuttoff Threshold Calculated Above Via Cost-Benefit Analysis

# %%
th_cross=roc_df.loc[roc_df.fp==fp_cross,'thresholds'].values[0]
preds_01 = predictions >=th_cross
preds_01=preds_01 *1
cnf_matrix = confusion_matrix(test_data_Y, preds_01)#.ravel()

ax=sns.heatmap(cnf_matrix,annot=True,fmt='d',cmap='YlGnBu')
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %% [markdown]
# ## Delete Endpoint (Just as a Cleanup)

# %%
sess.delete_endpoint(endpoint_name=device_failure_predictor.endpoint)
# Out:
# INFO:sagemaker:Deleting endpoint with name: device-failure-detection-endpoint-2018-12-15-02-15-10

# %% [markdown]
# # Other Links

# %% [markdown]
# https://github.com/awslabs/amazon-sagemaker-examples <br/>
# <a href="https://www.youtube.com/watch?v=FKY3A9RasGw">AWS re:Invent 2018: Build & Deploy ML Models Quickly & Easily with Amazon SageMaker (AIM404)</a>
